# %%
import pandas as pd
import geopandas
import numpy as np
import json
import matplotlib.pyplot as plt

# %%
#Get all the data files

vision_zero_df = pd.read_csv("data/vision_zero/Vision_Zero_Safety.csv")
three11_df = pd.read_csv("data/311_requests/311_City_Service_Requests_in_2020.csv")
street_segment_df = pd.read_csv("data/street_segments/Street_Segments.csv")
crash_df = pd.read_csv("data/crashes/Crashes_in_DC.csv")
street_functional_df = pd.read_csv("data/street_functional_classification/DDOT_Street_Functional_Classification.csv")
address_df = pd.read_csv("data/address_points/Address_Points.csv")
# Out:
# /home/banjtheman/miniconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (21,43,44) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
vision_zero_df
# Out:
#               X          Y  OBJECTID                                GLOBALID  \
# 0    -77.020315  38.892890         1  {7AA2347A-C035-4D5A-9196-07C309B4C7BF}
# 1    -77.020877  38.893046         2  {1AFF4069-5D94-49A1-9D1F-0A089D414F5F}
# 2    -77.024643  38.918125         3  {908CCF07-A389-40EE-B5D2-7ADAF90404D1}
# 3    -77.003515  38.896124         4  {12E7A594-76F9-41CE-91AC-9B6B8E08EC5C}
# 4    -77.017562  38.883266         5  {0AED48A8-A4DD-44E9-8C4A-D45E14E7462D}
# ...         ...        ...       ...                                     ...
# 5585 -76.999672  38.940749     65459  {4F51C0EE-49B9-462A-BFBC-0D3DB6A5C4CF}
# 5586 -77.013424  38.958740     65777  {CE23E3D5-105E-4270-8614-82E8CF633E20}
# 5587 -77.034612  38.919137     66097  {E812D839-6411-44AA-818F-E94C965B2030}
# 5588 -77.044876  38.914099     66113  {72C61DE6-5855-4CD8-9B6D-AE48BF2A7649}
# 5589 -77.088637  38.945544     66114  {C4649BAF-840E-4524-BA33-FE61099C1618}
#
#      REQUESTID               REQUESTTYPE             REQUESTDATE      STATUS  \
# 0            1    Blocking the crosswalk  2015/06/29 19:56:00+00  Unassigned
# 1            2       Other Driving Issue  2015/06/29 19:57:36+00  Unassigned
# 2            3  Not enough time to cross  2015/06/29 20:14:32+00  Unassigned
# 3            4         Stop sign running  2015/06/29 20:15:02+00  Unassigned
# 4            5          Cyclist behavior  2015/06/29 20:15:05+00  Unassigned
# ...        ...                       ...                     ...         ...
# 5585     65459      Blocking the bikebox  2019/10/10 13:49:23+00  Unassigned
# 5586     65777           Poor visibility  2020/01/02 23:32:16+00  Unassigned
# 5587     66097       Other Driving Issue  2020/01/14 00:04:22+00  Unassigned
# 5588     66113         Stop sign running  2020/02/12 17:49:49+00  Unassigned
# 5589     66114                  Speeding  2020/02/12 19:58:58+00  Unassigned
#
#       STREETSEGID                                           COMMENTS  \
# 0         10022.0  Cars for valet at the Capital Grille constantl...
# 1         10022.0                               Illegal U-Turns here
# 2         10396.0  There is no walk sign on this intersection so ...
# 3          4381.0  Constant issue; MPD never enforces despite rep...
# 4          5344.0             Some cyclists often run this red light
# ...           ...                                                ...
# 5585       3556.0  The short "bike lane" on Hawaii is routinely b...
# 5586       3077.0  This is a very dangerous intersection.  Way to...
# 5587       8670.0  Cars heading north on 15th try to take sharp l...
# 5588      11040.0  Drivers refuse to stop at the stop sign. DDOT ...
# 5589       5748.0              many speeders go through intersection
#
#         USERTYPE
# 0     Pedestrian
# 1     Pedestrian
# 2     Pedestrian
# 3     Pedestrian
# 4          Biker
# ...          ...
# 5585       Biker
# 5586  Pedestrian
# 5587       Biker
# 5588  Pedestrian
# 5589  Pedestrian
#
# [5590 rows x 11 columns]

# %%
three11_df
# Out:
#              X          Y  OBJECTID SERVICECODE        SERVICECODEDESCRIPTION  \
# 0   -77.011831  38.957475      1850    SPSTDAMA  Traffic Safety Investigation
# 1   -76.946948  38.900200      3676    SPSTDAMA  Traffic Safety Investigation
# 2   -77.008832  38.968958      4053    SPSTDAMA  Traffic Safety Investigation
# 3   -77.072913  38.932068      5418    SPSTDAMA  Traffic Safety Investigation
# 4   -77.055076  38.903968      6724    SPSTDAMA  Traffic Safety Investigation
# ..         ...        ...       ...         ...                           ...
# 822 -77.010676  38.916816    323076    SPSTDAMA  Traffic Safety Investigation
# 823 -76.917574  38.897390    323384    SPSTDAMA  Traffic Safety Investigation
# 824 -76.917328  38.886917    325640    SPSTDAMA  Traffic Safety Investigation
# 825 -76.960282  38.871654    325965    SPSTDAMA  Traffic Safety Investigation
# 826 -77.016544  38.941940    327580    SPSTDAMA  Traffic Safety Investigation
#
#        SERVICETYPECODEDESCRIPTION ORGANIZATIONACRONYM  SERVICECALLCOUNT  \
# 0    Department of Transportation                DDOT                 1
# 1    Department of Transportation                DDOT                 1
# 2    Department of Transportation                DDOT                 1
# 3    Department of Transportation                DDOT                 1
# 4    Department of Transportation                DDOT                 1
# ..                            ...                 ...               ...
# 822  Department of Transportation                DDOT                 1
# 823  Department of Transportation                DDOT                 1
# 824  Department of Transportation                DDOT                 1
# 825  Department of Transportation                DDOT                 1
# 826  Department of Transportation                DDOT                 1
#
#                     ADDDATE          RESOLUTIONDATE  ...     XCOORD  \
# 0    2020/01/02 09:33:13+00  1970/01/01 00:00:00+00  ...  398974.76
# 1    2020/01/03 09:36:22+00  2020/01/06 09:35:16+00  ...  404602.09
# 2    2020/01/03 13:28:34+00  2020/01/06 09:30:14+00  ...  399234.80
# 3    2020/01/04 11:41:57+00  2020/01/06 11:25:28+00  ...  393678.25
# 4    2020/01/05 08:30:46+00  2020/02/10 09:50:20+00  ...  395222.93
# ..                      ...                     ...  ...        ...
# 822  2020/08/04 12:39:24+00  1970/01/01 00:00:00+00  ...  399074.30
# 823  2020/08/04 17:53:07+00  1970/01/01 00:00:00+00  ...  407150.44
# 824  2020/08/05 10:21:36+00  1970/01/01 00:00:00+00  ...  407172.76
# 825  2020/08/05 15:35:02+00  1970/01/01 00:00:00+00  ...  403446.84
# 826  2020/08/06 12:40:17+00  1970/01/01 00:00:00+00  ...  398565.98
#
#         YCOORD   LATITUDE  LONGITUDE        CITY STATE  ZIPCODE  \
# 0    143284.72  38.957468 -77.011829  WASHINGTON    DC    20011
# 1    136927.98  38.900192 -76.946946  WASHINGTON    DC    20019
# 2    144559.46  38.968951 -77.008830  WASHINGTON    DC    20012
# 3    140466.80  38.932061 -77.072911  WASHINGTON    DC    20016
# 4    137346.40  38.903961 -77.055074  WASHINGTON    DC    20037
# ..         ...        ...        ...         ...   ...      ...
# 822  138771.19  38.916808 -77.010674  WASHINGTON    DC    20001
# 823  136617.90  38.897382 -76.917571  WASHINGTON    DC    20019
# 824  135455.41  38.886910 -76.917326  WASHINGTON    DC    20019
# 825  133758.52  38.871646 -76.960280  WASHINGTON    DC    20020
# 826  141560.24  38.941932 -77.016541  WASHINGTON    DC    20011
#
#     MARADDRESSREPOSITORYID WARD DETAILS
# 0                   245851  4.0     NaN
# 1                   316433  7.0     NaN
# 2                     1320  4.0     NaN
# 3                   221531  3.0     NaN
# 4                   274801  2.0     NaN
# ..                     ...  ...     ...
# 822                 227397  5.0     NaN
# 823                   5731  7.0     NaN
# 824                   6663  7.0     NaN
# 825                  38860  7.0     NaN
# 826                 244179  4.0     NaN
#
# [827 rows x 30 columns]

# %%
crash_df
# Out:
#                X          Y   OBJECTID   CRIMEID       CCN  \
# 0     -76.999401  38.843072  158115126  28491922  20112333
# 1     -76.933988  38.912487  158115127  28491795  20112288
# 2     -76.976971  38.896845  158115128  28491796  20112292
# 3     -77.047390  38.895693  158115129  28491670  20112161
# 4     -77.036191  38.992129  158115130  28491545  20112017
# ...          ...        ...        ...       ...       ...
# 10927 -76.952610  38.894914  158349304  28493652  20113080
# 10928 -76.988597  38.867478  158349305  28493774  20113222
# 10929 -76.925485  38.898355  158349306  28493881  20113346
# 10930 -76.916218  38.888462  158349307  28493656  20113089
# 10931 -76.914052  38.889233  158349308  28493684  20112928
#
#                    REPORTDATE          ROUTEID  MEASURE  OFFSET  STREETSEGID  \
# 0      2020/08/07 02:22:56+00         13009362    42.62    1.69          NaN
# 1      2020/08/06 20:15:10+00                0     0.00   40.08          NaN
# 2      2020/08/06 20:22:02+00         12076962   287.57    7.69          NaN
# 3      2020/08/06 15:18:02+00         11089892   706.40    0.03          NaN
# 4      2020/08/06 05:46:10+00         11031982  2768.83    4.60          NaN
# ...                       ...              ...      ...     ...          ...
# 10927  2020/08/08 14:32:55+00         12051803   717.13    6.34          NaN
# 10928  2020/08/08 20:31:23+00         13059452   156.06    3.08          NaN
# 10929  2020/08/09 00:56:45+00         12063252  1759.16   12.03          NaN
# 10930  2020/08/08 14:59:59+00  Route not found     0.00    0.00          NaN
# 10931  2020/08/08 16:33:24+00         13081512  9930.85   15.25          NaN
#
#        ...  MPDLATITUDE MPDLONGITUDE    MPDGEOX    MPDGEOY  \
# 0      ...    38.843079   -76.999400  400060.30  130562.84
# 1      ...    38.912796   -76.933764  405729.08  138250.97
# 2      ...    38.896905   -76.976950  402004.76  136567.07
# 3      ...    38.895685   -77.047387  395889.22  136427.33
# 4      ...    38.992144   -77.036144        NaN        NaN
# ...    ...          ...          ...        ...        ...
# 10927  ...    38.894865   -76.952557  404270.30  136174.27
# 10928  ...    38.867459   -76.988562  401036.42  133305.38
# 10929  ...    38.898239   -76.925483  406479.18  136684.81
# 10930  ...    38.888454   -76.916216  407268.89  135626.92
# 10931  ...    38.889129   -76.913925  407313.45  135656.64
#
#                                BLOCKKEY                       SUBBLOCKKEY  \
# 0      56aef9357e7d558f4ed50261781de7d0  56aef9357e7d558f4ed50261781de7d0
# 1      84070d228553c09f5cbc6eb393bc4274  b560c1d968377deab6c4a72cfb312803
# 2      f7a29ddaec7710eab2883510228f8434  f7a29ddaec7710eab2883510228f8434
# 3      43c42f042dc40dda36a34a278cfb127a  43c42f042dc40dda36a34a278cfb127a
# 4      539f524ee3a9531c085e4910ae75594f  539f524ee3a9531c085e4910ae75594f
# ...                                 ...                               ...
# 10927  1603adbe725379b6562aa160fddc209e  c056627c9845bf4a3f18037e9161c98e
# 10928  fdf573727bc15d36e65984f31bfe71e0  fdf573727bc15d36e65984f31bfe71e0
# 10929  fd2de70a50c81854a3160b7a559d40f1  fd2de70a50c81854a3160b7a559d40f1
# 10930                           Unknown                           Unknown
# 10931  8fd3e5123921a7f290298d3a378c4aec  8fd3e5123921a7f290298d3a378c4aec
#
#        FATALPASSENGER  MAJORINJURIESPASSENGER  MINORINJURIESPASSENGER  \
# 0                   0                       0                       0
# 1                   0                       0                       0
# 2                   0                       0                       0
# 3                   0                       0                       0
# 4                   0                       0                       0
# ...               ...                     ...                     ...
# 10927               0                       0                       0
# 10928               0                       0                       0
# 10929               0                       0                       0
# 10930               0                       0                       0
# 10931               0                       0                       0
#
#       UNKNOWNINJURIESPASSENGER
# 0                            0
# 1                            0
# 2                            0
# 3                            0
# 4                            0
# ...                        ...
# 10927                        0
# 10928                        0
# 10929                        0
# 10930                        0
# 10931                        0
#
# [10932 rows x 60 columns]

# %%
address_df
# Out:
#                 X          Y  OBJECTID_12  OBJECTID  SITE_ADDRESS_PK  \
# 0      -77.000353  38.892195       832017    1087.0            27746
# 1      -76.999249  38.892652       832018    3265.0            50808
# 2      -76.999769  38.892558       832019    3266.0            51065
# 3      -76.999231  38.892546       832020    3267.0            51219
# 4      -76.997461  38.892194       832021       1.0             3171
# ...           ...        ...          ...       ...              ...
# 148052 -76.983941  38.856912      1040981       NaN           331747
# 148053 -76.983930  38.856859      1040982       NaN           331748
# 148054 -76.983941  38.857058      1041297       NaN           331736
# 148055 -76.983938  38.857021      1041298       NaN           331738
# 148056 -76.983940  38.856947      1041299       NaN           331739
#
#         ADDRESS_ID  ROADWAYSEGID    STATUS           SSL    TYPE_  ...  \
# 0            27746       11690.0    ACTIVE  0814    0018  ADDRESS  ...
# 1            50808        3073.0    ACTIVE  0838    0027  ADDRESS  ...
# 2            51065        3073.0    ACTIVE  0814    0818  ADDRESS  ...
# 3            51219        3073.0    ACTIVE  0838    0041  ADDRESS  ...
# 4             3171        9646.0    ACTIVE  0866    0013  ADDRESS  ...
# ...            ...           ...       ...           ...      ...  ...
# 148052      331747        6069.0  ASSIGNED  5828    0035  ADDRESS  ...
# 148053      331748        6069.0  ASSIGNED  5828    0036  ADDRESS  ...
# 148054      331736        6069.0  ASSIGNED  5828    0032  ADDRESS  ...
# 148055      331738        6069.0  ASSIGNED  5828    0033  ADDRESS  ...
# 148056      331739        6069.0  ASSIGNED  5828    0034  ADDRESS  ...
#
#         LONGITUDE  ACTIVE_RES_UNIT_COUNT     RES_TYPE  \
# 0      -77.000351                    0.0  RESIDENTIAL
# 1      -76.999247                    0.0  RESIDENTIAL
# 2      -76.999767                    1.0  RESIDENTIAL
# 3      -76.999229                    0.0  RESIDENTIAL
# 4      -76.997459                    1.0  RESIDENTIAL
# ...           ...                    ...          ...
# 148052 -76.983938                    0.0  RESIDENTIAL
# 148053 -76.983927                    0.0  RESIDENTIAL
# 148054 -76.983939                    0.0  RESIDENTIAL
# 148055 -76.983935                    0.0  RESIDENTIAL
# 148056 -76.983937                    0.0  RESIDENTIAL
#
#        ACTIVE_RES_OCCUPANCY_COUNT WARD_2002 WARD_2012 ANC_2002 ANC_2012  \
# 0                             1.0    Ward 6    Ward 6   ANC 6C   ANC 6C
# 1                             1.0    Ward 6    Ward 6   ANC 6C   ANC 6C
# 2                             2.0    Ward 6    Ward 6   ANC 6C   ANC 6C
# 3                             1.0    Ward 6    Ward 6   ANC 6C   ANC 6C
# 4                             2.0    Ward 6    Ward 6   ANC 6C   ANC 6C
# ...                           ...       ...       ...      ...      ...
# 148052                        0.0    Ward 8    Ward 8   ANC 8A   ANC 8B
# 148053                        0.0    Ward 8    Ward 8   ANC 8A   ANC 8B
# 148054                        0.0    Ward 8    Ward 8   ANC 8A   ANC 8B
# 148055                        0.0    Ward 8    Ward 8   ANC 8A   ANC 8B
# 148056                        0.0    Ward 8    Ward 8   ANC 8A   ANC 8B
#
#         SMD_2002  SMD_2012
# 0       SMD 6C07  SMD 6C03
# 1       SMD 6C07  SMD 6C03
# 2       SMD 6C07  SMD 6C03
# 3       SMD 6C07  SMD 6C03
# 4       SMD 6C07  SMD 6C03
# ...          ...       ...
# 148052  SMD 8A07  SMD 8B04
# 148053  SMD 8A07  SMD 8B04
# 148054  SMD 8A07  SMD 8B04
# 148055  SMD 8A07  SMD 8B04
# 148056  SMD 8A07  SMD 8B04
#
# [148057 rows x 60 columns]

# %%
street_segment_df
# Out:
#        STREETSEGID   FACILITYID  SOURCEID  STREETID REGISTEREDNAME STREETTYPE  \
# 0             2466   SEGID-2466  10190160    100190           19TH         ST
# 1              648    SEGID-648  10190165    100190           19TH         ST
# 2            10440  SEGID-10440  10190170    100190           19TH         ST
# 3            11369  SEGID-11369  10190175    100190           19TH         ST
# 4             1872   SEGID-1872  10190180    100190           19TH         ST
# ...            ...          ...       ...       ...            ...        ...
# 13671        15300   SEGID-7265  47642003    407642        ROBBINS         RD
# 13672        15237   SEGID-4648  46640471    406640        OBERLIN        AVE
# 13673        15238   SEGID-8345  43674470    403674          FOLEY        AVE
# 13674        15800  SEGID-15608  19229127    109229           WEST         RD
# 13675        15801  SEGID-15801  17247380    107247       PROSPECT         ST
#
#       QUADRANT  DIRECTIONALITY  SEGMENTTYPE  FROMNODEID  ...  \
# 0           NW               2            2       15597  ...
# 1           NW               2            2       17019  ...
# 2           NW               2            2       21789  ...
# 3           NW               2            2       21790  ...
# 4           NW               2            2       21881  ...
# ...        ...             ...          ...         ...  ...
# 13671       SW               2            2       24744  ...
# 13672       SW               2            2       24717  ...
# 13673       SW               2            2       21898  ...
# 13674       NW               2            2       24987  ...
# 13675       NW               2            2       13457  ...
#
#        FROMADDRESSLEFTTHEO  TOADDRESSLEFTTHEO  FROMADDRESSRIGHTTHEO  \
# 0                   1600.0             1622.0                1601.0
# 1                   1624.0             1698.0                1623.0
# 2                   1700.0             1720.0                1701.0
# 3                   1722.0             1798.0                1721.0
# 4                   1800.0             1818.0                1801.0
# ...                    ...                ...                   ...
# 13671                  0.0                0.0                   0.0
# 13672                  0.0                0.0                   0.0
# 13673                  0.0                0.0                   0.0
# 13674                  0.0                0.0                   0.0
# 13675                  0.0                0.0                   0.0
#
#        TOADDRESSRIGHTTHEO  BEGINMEASURE  ENDMEASURE         UPDATETIMESTAMP  \
# 0                  1621.0             0   82.093792  2005/11/01 16:55:47+00
# 1                  1699.0             0   82.047684  2005/11/01 16:55:47+00
# 2                  1721.0             0   84.062920  2005/11/01 16:55:47+00
# 3                  1799.0             0   80.407119  2005/11/01 16:55:47+00
# 4                  1819.0             0   82.485227  2005/11/01 16:55:47+00
# ...                   ...           ...         ...                     ...
# 13671                 0.0             0   53.853207  2014/11/03 19:04:43+00
# 13672                 0.0             0   24.027493  2014/10/23 19:14:38+00
# 13673                 0.0             0   13.628433  2016/12/13 20:07:23+00
# 13674                 0.0             0  173.305477  2018/06/05 15:38:54+00
# 13675                 0.0             0   79.322183  2018/06/08 15:03:49+00
#
#       OBJECTID_1  OBJECTID    SHAPELEN
# 0        2546144   2684355   82.093750
# 1        2546241   2684356   82.047679
# 2        2546242   2684357   84.062956
# 3        2546243   2684358   80.407097
# 4        2546244   2684359   82.485217
# ...          ...       ...         ...
# 13671    2559911   2696594   53.853196
# 13672    2559912   2696595   24.027547
# 13673    2559913   2696596   13.628415
# 13674    2559914   2696597  173.305479
# 13675    2559915   2696598   79.322206
#
# [13676 rows x 21 columns]

# %%
vision_three_merge = pd.merge(vision_zero_df, street_segment_df, on=["X","Y"], how='inner')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-aa0125e38d6f> in <module>
# ----> 1 vision_three_merge = pd.merge(vision_zero_df, street_segment_df, on=["X","Y"], how='inner')
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      85         copy=copy,
#      86         indicator=indicator,
# ---> 87         validate=validate,
#      88     )
#      89     return op.get_result()
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     650             self.right_join_keys,
#     651             self.join_names,
# --> 652         ) = self._get_merge_keys()
#     653
#     654         # validate the merge keys dtypes. We may need to coerce
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#    1003                     if not is_rkey(rk):
#    1004                         if rk is not None:
# -> 1005                             right_keys.append(right._get_label_or_level_values(rk))
#    1006                         else:
#    1007                             # work-around for merge_asof(right_index=True)
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1558             values = self.axes[axis].get_level_values(key)._values
#    1559         else:
# -> 1560             raise KeyError(key)
#    1561
#    1562         # Check for duplicates
#
# KeyError: 'X'

# %%
vision_three_merge
# Out:
# Empty DataFrame
# Columns: [X, Y, OBJECTID_x, GLOBALID, REQUESTID, REQUESTTYPE, REQUESTDATE, STATUS_x, STREETSEGID, COMMENTS, USERTYPE, geometry, OBJECTID_12, OBJECTID_y, SITE_ADDRESS_PK, ADDRESS_ID, ROADWAYSEGID, STATUS_y, SSL, TYPE_, ENTRANCETYPE, ADDRNUM, ADDRNUMSUFFIX, STNAME, STREET_TYPE, QUADRANT, CITY, STATE, FULLADDRESS, SQUARE, SUFFIX, LOT, NATIONALGRID, ZIPCODE4, XCOORD, YCOORD, STATUS_ID, METADATA_ID, OBJECTID_1, ASSESSMENT_NBHD, ASSESSMENT_SUBNBHD, CFSA_NAME, HOTSPOT, CLUSTER_, POLDIST, ROC, PSA, SMD, CENSUS_TRACT, VOTE_PRCNCT, WARD, ZIPCODE, ANC, NEWCOMMSELECT06, NEWCOMMCANDIDATE, CENSUS_BLOCK, CENSUS_BLOCKGROUP, FOCUS_IMPROVEMENT_AREA, SE_ANNO_CAD_DATA, LATITUDE, LONGITUDE, ACTIVE_RES_UNIT_COUNT, RES_TYPE, ACTIVE_RES_OCCUPANCY_COUNT, WARD_2002, WARD_2012, ANC_2002, ANC_2012, SMD_2002, SMD_2012]
# Index: []
#
# [0 rows x 70 columns]

# %%
vision_gdf = geopandas.GeoDataFrame(
    vision_zero_df, geometry=geopandas.points_from_xy(vision_zero_df.X, vision_zero_df.Y))

# %%
print(vision_gdf.head())
# Out:
#            X          Y  OBJECTID                                GLOBALID  \
# 0 -77.020315  38.892890         1  {7AA2347A-C035-4D5A-9196-07C309B4C7BF}
# 1 -77.020877  38.893046         2  {1AFF4069-5D94-49A1-9D1F-0A089D414F5F}
# 2 -77.024643  38.918125         3  {908CCF07-A389-40EE-B5D2-7ADAF90404D1}
# 3 -77.003515  38.896124         4  {12E7A594-76F9-41CE-91AC-9B6B8E08EC5C}
# 4 -77.017562  38.883266         5  {0AED48A8-A4DD-44E9-8C4A-D45E14E7462D}
#
#   REQUESTID               REQUESTTYPE             REQUESTDATE      STATUS  \
# 0         1    Blocking the crosswalk  2015/06/29 19:56:00+00  Unassigned
# 1         2       Other Driving Issue  2015/06/29 19:57:36+00  Unassigned
# 2         3  Not enough time to cross  2015/06/29 20:14:32+00  Unassigned
# 3         4         Stop sign running  2015/06/29 20:15:02+00  Unassigned
# 4         5          Cyclist behavior  2015/06/29 20:15:05+00  Unassigned
#
#    STREETSEGID                                           COMMENTS    USERTYPE  \
# 0      10022.0  Cars for valet at the Capital Grille constantl...  Pedestrian
# 1      10022.0                               Illegal U-Turns here  Pedestrian
# 2      10396.0  There is no walk sign on this intersection so ...  Pedestrian
# 3       4381.0  Constant issue; MPD never enforces despite rep...  Pedestrian
# 4       5344.0             Some cyclists often run this red light       Biker
#
#                      geometry
# 0  POINT (-77.02031 38.89289)
# 1  POINT (-77.02088 38.89305)
# 2  POINT (-77.02464 38.91813)
# 3  POINT (-77.00351 38.89612)
# 4  POINT (-77.01756 38.88327)

# %%
geopandas.datasets.available
# Out:
# ['naturalearth_cities', 'naturalearth_lowres', 'nybb']

# %%
# cities = geopandas.read_file(geopandas.datasets.get_path('naturalearth_cities'))


# #ax = usa[usa.STATE_ABBR == "DC"]
# ax = world[world.continent == 'North America'].plot(
#     color='white', edgecolor='black')

# # We can now plot our ``GeoDataFrame``.
# vision_gdf.plot(ax=cities, color='red')

# plt.show()
